# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x).relu()
    h2 = self.linear2(h1).relu() + h1  # Residual connection
    h3 = self.linear3(h2).relu() + h2  # Residual connection
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('int'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('int'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 300
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.573956, train error 60.03,  val loss 1.640632, percent error 64.50
# Epoch     1, train loss 1.261327, train error 45.50,  val loss 1.412334, percent error 55.50
# Epoch     2, train loss 1.071383, train error 38.30,  val loss 1.275082, percent error 48.00
# Epoch     3, train loss 0.958583, train error 35.80,  val loss 1.205492, percent error 47.30
# Epoch     4, train loss 0.842090, train error 31.18,  val loss 1.148172, percent error 43.70
# Epoch     5, train loss 0.755968, train error 28.10,  val loss 1.150467, percent error 42.80
# Epoch     6, train loss 0.684158, train error 24.90,  val loss 1.127164, percent error 43.10
# Epoch     7, train loss 0.703745, train error 25.62,  val loss 1.230811, percent error 44.90
# Epoch     8, train loss 0.572410, train error 21.35,  val loss 1.130677, percent error 39.20
# Epoch     9, train loss 0.530030, train error 19.07,  val loss 1.127114, percent error 40.30
# Epoch    10, train loss 0.519312, train error 18.72,  val loss 1.249850, percent error 43.20
# Epoch    11, train loss 0.444011, train error 16.12,  val loss 1.169270, percent error 39.40
# Epoch    12, train loss 0.369382, train error 12.10,  val loss 1.216408, percent error 40.60
# Epoch    13, train loss 0.298656, train error 9.68,  val loss 1.156449, percent error 37.50
# Epoch    14, train loss 0.303948, train error 11.03,  val loss 1.349544, percent error 38.40
# Epoch    15, train loss 0.267936, train error 9.22,  val loss 1.260239, percent error 37.90
# Epoch    16, train loss 0.199608, train error 6.22,  val loss 1.279270, percent error 35.90
# Epoch    17, train loss 0.221216, train error 6.97,  val loss 1.307055, percent error 38.10
# Epoch    18, train loss 0.187533, train error 6.03,  val loss 1.351951, percent error 35.20
# Epoch    19, train loss 0.222563, train error 8.18,  val loss 1.517921, percent error 36.70
# Epoch    20, train loss 0.064296, train error 0.57,  val loss 1.328529, percent error 36.00
# Epoch    21, train loss 0.047007, train error 0.05,  val loss 1.324594, percent error 34.40
# Epoch    22, train loss 0.033366, train error 0.00,  val loss 1.348647, percent error 35.10
# Epoch    23, train loss 0.027615, train error 0.00,  val loss 1.361764, percent error 34.20
# Epoch    24, train loss 0.024471, train error 0.00,  val loss 1.406911, percent error 35.10
# Epoch    25, train loss 0.021714, train error 0.00,  val loss 1.419309, percent error 35.40
# Epoch    26, train loss 0.019270, train error 0.00,  val loss 1.434776, percent error 34.80
# Epoch    27, train loss 0.017395, train error 0.00,  val loss 1.448789, percent error 34.50
# Epoch    28, train loss 0.016094, train error 0.00,  val loss 1.475533, percent error 35.00
# Epoch    29, train loss 0.014643, train error 0.00,  val loss 1.494934, percent error 35.20
# Epoch    30, train loss 0.013546, train error 0.00,  val loss 1.499694, percent error 34.50
# Epoch    31, train loss 0.012631, train error 0.00,  val loss 1.519553, percent error 35.20
# Epoch    32, train loss 0.011938, train error 0.00,  val loss 1.536482, percent error 35.50
# Epoch    33, train loss 0.011165, train error 0.00,  val loss 1.549514, percent error 35.30
# Epoch    34, train loss 0.010738, train error 0.00,  val loss 1.567199, percent error 34.90
# Epoch    35, train loss 0.009815, train error 0.00,  val loss 1.575959, percent error 35.50
# Epoch    36, train loss 0.009395, train error 0.00,  val loss 1.590344, percent error 35.30
# Epoch    37, train loss 0.008925, train error 0.00,  val loss 1.594512, percent error 34.90
# Epoch    38, train loss 0.008433, train error 0.00,  val loss 1.604915, percent error 34.90
# Epoch    39, train loss 0.008005, train error 0.00,  val loss 1.615440, percent error 35.10
# Epoch    40, train loss 0.007803, train error 0.00,  val loss 1.620514, percent error 34.50
# Epoch    41, train loss 0.007621, train error 0.00,  val loss 1.623585, percent error 35.10
# Epoch    42, train loss 0.007453, train error 0.00,  val loss 1.632016, percent error 34.80
# Epoch    43, train loss 0.007300, train error 0.00,  val loss 1.635117, percent error 34.80
# Epoch    44, train loss 0.007147, train error 0.00,  val loss 1.641091, percent error 34.80
# Epoch    45, train loss 0.007002, train error 0.00,  val loss 1.645888, percent error 34.60
# Epoch    46, train loss 0.006878, train error 0.00,  val loss 1.648910, percent error 34.70
# Epoch    47, train loss 0.006727, train error 0.00,  val loss 1.654109, percent error 34.50
# Epoch    48, train loss 0.006610, train error 0.00,  val loss 1.659580, percent error 35.10
# Epoch    49, train loss 0.006477, train error 0.00,  val loss 1.662548, percent error 34.40
# Epoch    50, train loss 0.006354, train error 0.00,  val loss 1.667392, percent error 34.70
# Epoch    51, train loss 0.006246, train error 0.00,  val loss 1.671379, percent error 35.00
# Epoch    52, train loss 0.006126, train error 0.00,  val loss 1.676892, percent error 34.70
# Epoch    53, train loss 0.006019, train error 0.00,  val loss 1.677982, percent error 34.60
# Epoch    54, train loss 0.005912, train error 0.00,  val loss 1.681776, percent error 34.50
# Epoch    55, train loss 0.005814, train error 0.00,  val loss 1.686813, percent error 34.80
# Epoch    56, train loss 0.005708, train error 0.00,  val loss 1.689799, percent error 34.10
# Epoch    57, train loss 0.005619, train error 0.00,  val loss 1.695872, percent error 34.70
# Epoch    58, train loss 0.005517, train error 0.00,  val loss 1.697803, percent error 34.40
# Epoch    59, train loss 0.005436, train error 0.00,  val loss 1.700313, percent error 34.50
# Epoch    60, train loss 0.005377, train error 0.00,  val loss 1.703097, percent error 34.60
# Epoch    61, train loss 0.005333, train error 0.00,  val loss 1.704985, percent error 34.30
# Epoch    62, train loss 0.005290, train error 0.00,  val loss 1.706644, percent error 34.60
# Epoch    63, train loss 0.005248, train error 0.00,  val loss 1.709442, percent error 34.50
# Epoch    64, train loss 0.005207, train error 0.00,  val loss 1.710654, percent error 34.40
# Epoch    65, train loss 0.005166, train error 0.00,  val loss 1.712670, percent error 34.60
# Epoch    66, train loss 0.005126, train error 0.00,  val loss 1.715135, percent error 34.60
# Epoch    67, train loss 0.005086, train error 0.00,  val loss 1.716325, percent error 34.70
# Epoch    68, train loss 0.005046, train error 0.00,  val loss 1.718000, percent error 34.50
# Epoch    69, train loss 0.005008, train error 0.00,  val loss 1.720212, percent error 34.40
# Epoch    70, train loss 0.004970, train error 0.00,  val loss 1.721915, percent error 34.40
# Epoch    71, train loss 0.004933, train error 0.00,  val loss 1.723071, percent error 34.50
# Epoch    72, train loss 0.004896, train error 0.00,  val loss 1.725572, percent error 34.60
# Epoch    73, train loss 0.004858, train error 0.00,  val loss 1.727309, percent error 34.40
# Epoch    74, train loss 0.004822, train error 0.00,  val loss 1.728024, percent error 34.50
# Epoch    75, train loss 0.004787, train error 0.00,  val loss 1.730930, percent error 34.70
# Epoch    76, train loss 0.004751, train error 0.00,  val loss 1.732161, percent error 34.60
# Epoch    77, train loss 0.004716, train error 0.00,  val loss 1.734087, percent error 34.50
# Epoch    78, train loss 0.004682, train error 0.00,  val loss 1.735274, percent error 34.50
# Epoch    79, train loss 0.004649, train error 0.00,  val loss 1.736827, percent error 34.70
# Epoch    80, train loss 0.004630, train error 0.00,  val loss 1.738301, percent error 34.80
# Epoch    81, train loss 0.004613, train error 0.00,  val loss 1.738700, percent error 34.70
# Epoch    82, train loss 0.004597, train error 0.00,  val loss 1.739742, percent error 34.70
# Epoch    83, train loss 0.004581, train error 0.00,  val loss 1.740340, percent error 34.60
# Epoch    84, train loss 0.004564, train error 0.00,  val loss 1.741254, percent error 34.70
# Epoch    85, train loss 0.004548, train error 0.00,  val loss 1.742072, percent error 34.80
# Epoch    86, train loss 0.004532, train error 0.00,  val loss 1.743097, percent error 34.70
# Epoch    87, train loss 0.004516, train error 0.00,  val loss 1.743693, percent error 34.70
# Epoch    88, train loss 0.004500, train error 0.00,  val loss 1.744271, percent error 34.60
# Epoch    89, train loss 0.004484, train error 0.00,  val loss 1.745762, percent error 34.70
# Epoch    90, train loss 0.004468, train error 0.00,  val loss 1.746410, percent error 34.70
# Epoch    91, train loss 0.004453, train error 0.00,  val loss 1.746914, percent error 34.60
# Epoch    92, train loss 0.004437, train error 0.00,  val loss 1.747776, percent error 34.70
# Epoch    93, train loss 0.004422, train error 0.00,  val loss 1.748340, percent error 34.80
# Epoch    94, train loss 0.004407, train error 0.00,  val loss 1.749202, percent error 34.60
# Epoch    95, train loss 0.004391, train error 0.00,  val loss 1.750068, percent error 34.70
# Epoch    96, train loss 0.004376, train error 0.00,  val loss 1.750679, percent error 34.60
# Epoch    97, train loss 0.004361, train error 0.00,  val loss 1.751837, percent error 34.70
# Epoch    98, train loss 0.004346, train error 0.00,  val loss 1.752139, percent error 34.70
# Epoch    99, train loss 0.004331, train error 0.00,  val loss 1.752800, percent error 34.60
# Epoch   100, train loss 0.004324, train error 0.00,  val loss 1.753493, percent error 34.60
# Epoch   101, train loss 0.004316, train error 0.00,  val loss 1.753789, percent error 34.60
# Epoch   102, train loss 0.004309, train error 0.00,  val loss 1.754061, percent error 34.60
# Epoch   103, train loss 0.004301, train error 0.00,  val loss 1.754520, percent error 34.60
# Epoch   104, train loss 0.004294, train error 0.00,  val loss 1.755160, percent error 34.70
# Epoch   105, train loss 0.004287, train error 0.00,  val loss 1.755444, percent error 34.60
# Epoch   106, train loss 0.004280, train error 0.00,  val loss 1.755712, percent error 34.60
# Epoch   107, train loss 0.004272, train error 0.00,  val loss 1.756226, percent error 34.70
# Epoch   108, train loss 0.004265, train error 0.00,  val loss 1.756599, percent error 34.60
# Epoch   109, train loss 0.004258, train error 0.00,  val loss 1.756727, percent error 34.60
# Epoch   110, train loss 0.004251, train error 0.00,  val loss 1.757413, percent error 34.70
# Epoch   111, train loss 0.004244, train error 0.00,  val loss 1.757499, percent error 34.60
# Epoch   112, train loss 0.004237, train error 0.00,  val loss 1.758119, percent error 34.60
# Epoch   113, train loss 0.004229, train error 0.00,  val loss 1.758436, percent error 34.60
# Epoch   114, train loss 0.004222, train error 0.00,  val loss 1.758733, percent error 34.60
# Epoch   115, train loss 0.004215, train error 0.00,  val loss 1.759191, percent error 34.60
# Epoch   116, train loss 0.004208, train error 0.00,  val loss 1.759518, percent error 34.60
# Epoch   117, train loss 0.004201, train error 0.00,  val loss 1.760034, percent error 34.70
# Epoch   118, train loss 0.004194, train error 0.00,  val loss 1.760161, percent error 34.60
# Epoch   119, train loss 0.004187, train error 0.00,  val loss 1.760845, percent error 34.70
# Epoch   120, train loss 0.004184, train error 0.00,  val loss 1.761021, percent error 34.60
# Epoch   121, train loss 0.004180, train error 0.00,  val loss 1.761152, percent error 34.60
# Epoch   122, train loss 0.004177, train error 0.00,  val loss 1.761308, percent error 34.60
# Epoch   123, train loss 0.004173, train error 0.00,  val loss 1.761565, percent error 34.60
# Epoch   124, train loss 0.004170, train error 0.00,  val loss 1.761731, percent error 34.60
# Epoch   125, train loss 0.004166, train error 0.00,  val loss 1.761875, percent error 34.60
# Epoch   126, train loss 0.004163, train error 0.00,  val loss 1.762066, percent error 34.60
# Epoch   127, train loss 0.004159, train error 0.00,  val loss 1.762329, percent error 34.60
# Epoch   128, train loss 0.004156, train error 0.00,  val loss 1.762553, percent error 34.60
# Epoch   129, train loss 0.004152, train error 0.00,  val loss 1.762740, percent error 34.60
# Epoch   130, train loss 0.004149, train error 0.00,  val loss 1.762855, percent error 34.60
# Epoch   131, train loss 0.004146, train error 0.00,  val loss 1.763112, percent error 34.60
# Epoch   132, train loss 0.004142, train error 0.00,  val loss 1.763351, percent error 34.70
# Epoch   133, train loss 0.004139, train error 0.00,  val loss 1.763376, percent error 34.60
# Epoch   134, train loss 0.004135, train error 0.00,  val loss 1.763603, percent error 34.60
# Epoch   135, train loss 0.004132, train error 0.00,  val loss 1.763819, percent error 34.60
# Epoch   136, train loss 0.004129, train error 0.00,  val loss 1.764114, percent error 34.70
# Epoch   137, train loss 0.004125, train error 0.00,  val loss 1.764149, percent error 34.60
# Epoch   138, train loss 0.004122, train error 0.00,  val loss 1.764377, percent error 34.60
# Epoch   139, train loss 0.004118, train error 0.00,  val loss 1.764589, percent error 34.60
# Epoch   140, train loss 0.004117, train error 0.00,  val loss 1.764702, percent error 34.60
# Epoch   141, train loss 0.004115, train error 0.00,  val loss 1.764816, percent error 34.60
# Epoch   142, train loss 0.004113, train error 0.00,  val loss 1.764868, percent error 34.60
# Epoch   143, train loss 0.004112, train error 0.00,  val loss 1.764961, percent error 34.60
# Epoch   144, train loss 0.004110, train error 0.00,  val loss 1.765100, percent error 34.60
# Epoch   145, train loss 0.004108, train error 0.00,  val loss 1.765132, percent error 34.60
# Epoch   146, train loss 0.004107, train error 0.00,  val loss 1.765220, percent error 34.60
# Epoch   147, train loss 0.004105, train error 0.00,  val loss 1.765392, percent error 34.70
# Epoch   148, train loss 0.004103, train error 0.00,  val loss 1.765418, percent error 34.60
# Epoch   149, train loss 0.004102, train error 0.00,  val loss 1.765562, percent error 34.60
# Epoch   150, train loss 0.004100, train error 0.00,  val loss 1.765650, percent error 34.60
# Epoch   151, train loss 0.004098, train error 0.00,  val loss 1.765756, percent error 34.60
# Epoch   152, train loss 0.004096, train error 0.00,  val loss 1.765818, percent error 34.60
# Epoch   153, train loss 0.004095, train error 0.00,  val loss 1.765895, percent error 34.60
# Epoch   154, train loss 0.004093, train error 0.00,  val loss 1.765996, percent error 34.60
# Epoch   155, train loss 0.004092, train error 0.00,  val loss 1.766097, percent error 34.60
# Epoch   156, train loss 0.004090, train error 0.00,  val loss 1.766216, percent error 34.60
# Epoch   157, train loss 0.004088, train error 0.00,  val loss 1.766287, percent error 34.60
# Epoch   158, train loss 0.004087, train error 0.00,  val loss 1.766370, percent error 34.60
# Epoch   159, train loss 0.004085, train error 0.00,  val loss 1.766493, percent error 34.60
# Epoch   160, train loss 0.004084, train error 0.00,  val loss 1.766523, percent error 34.60
# Epoch   161, train loss 0.004083, train error 0.00,  val loss 1.766576, percent error 34.60
# Epoch   162, train loss 0.004082, train error 0.00,  val loss 1.766631, percent error 34.60
# Epoch   163, train loss 0.004082, train error 0.00,  val loss 1.766681, percent error 34.60
# Epoch   164, train loss 0.004081, train error 0.00,  val loss 1.766719, percent error 34.60
# Epoch   165, train loss 0.004080, train error 0.00,  val loss 1.766788, percent error 34.60
# Epoch   166, train loss 0.004079, train error 0.00,  val loss 1.766814, percent error 34.60
# Epoch   167, train loss 0.004078, train error 0.00,  val loss 1.766881, percent error 34.60
# Epoch   168, train loss 0.004077, train error 0.00,  val loss 1.766902, percent error 34.60
# Epoch   169, train loss 0.004077, train error 0.00,  val loss 1.766958, percent error 34.60
# Epoch   170, train loss 0.004076, train error 0.00,  val loss 1.767017, percent error 34.60
# Epoch   171, train loss 0.004075, train error 0.00,  val loss 1.767028, percent error 34.60
# Epoch   172, train loss 0.004074, train error 0.00,  val loss 1.767111, percent error 34.60
# Epoch   173, train loss 0.004073, train error 0.00,  val loss 1.767110, percent error 34.60
# Epoch   174, train loss 0.004072, train error 0.00,  val loss 1.767197, percent error 34.60
# Epoch   175, train loss 0.004072, train error 0.00,  val loss 1.767267, percent error 34.60
# Epoch   176, train loss 0.004071, train error 0.00,  val loss 1.767295, percent error 34.60
# Epoch   177, train loss 0.004070, train error 0.00,  val loss 1.767332, percent error 34.60
# Epoch   178, train loss 0.004069, train error 0.00,  val loss 1.767390, percent error 34.60
# Epoch   179, train loss 0.004068, train error 0.00,  val loss 1.767424, percent error 34.60
# Epoch   180, train loss 0.004068, train error 0.00,  val loss 1.767433, percent error 34.60
# Epoch   181, train loss 0.004067, train error 0.00,  val loss 1.767472, percent error 34.60
# Epoch   182, train loss 0.004067, train error 0.00,  val loss 1.767498, percent error 34.60
# Epoch   183, train loss 0.004067, train error 0.00,  val loss 1.767521, percent error 34.60
# Epoch   184, train loss 0.004066, train error 0.00,  val loss 1.767542, percent error 34.60
# Epoch   185, train loss 0.004066, train error 0.00,  val loss 1.767581, percent error 34.60
# Epoch   186, train loss 0.004065, train error 0.00,  val loss 1.767602, percent error 34.60
# Epoch   187, train loss 0.004065, train error 0.00,  val loss 1.767622, percent error 34.60
# Epoch   188, train loss 0.004065, train error 0.00,  val loss 1.767645, percent error 34.60
# Epoch   189, train loss 0.004064, train error 0.00,  val loss 1.767667, percent error 34.60
# Epoch   190, train loss 0.004064, train error 0.00,  val loss 1.767670, percent error 34.60
# Epoch   191, train loss 0.004063, train error 0.00,  val loss 1.767709, percent error 34.60
# Epoch   192, train loss 0.004063, train error 0.00,  val loss 1.767728, percent error 34.60
# Epoch   193, train loss 0.004062, train error 0.00,  val loss 1.767759, percent error 34.60
# Epoch   194, train loss 0.004062, train error 0.00,  val loss 1.767789, percent error 34.60
# Epoch   195, train loss 0.004062, train error 0.00,  val loss 1.767810, percent error 34.60
# Epoch   196, train loss 0.004061, train error 0.00,  val loss 1.767843, percent error 34.60
# Epoch   197, train loss 0.004061, train error 0.00,  val loss 1.767852, percent error 34.60
# Epoch   198, train loss 0.004060, train error 0.00,  val loss 1.767876, percent error 34.60
# Epoch   199, train loss 0.004060, train error 0.00,  val loss 1.767908, percent error 34.60
# Epoch   200, train loss 0.004060, train error 0.00,  val loss 1.767923, percent error 34.60
# Epoch   201, train loss 0.004060, train error 0.00,  val loss 1.767928, percent error 34.60
# Epoch   202, train loss 0.004059, train error 0.00,  val loss 1.767944, percent error 34.60
# Epoch   203, train loss 0.004059, train error 0.00,  val loss 1.767951, percent error 34.60
# Epoch   204, train loss 0.004059, train error 0.00,  val loss 1.767972, percent error 34.60
# Epoch   205, train loss 0.004059, train error 0.00,  val loss 1.767974, percent error 34.60
# Epoch   206, train loss 0.004059, train error 0.00,  val loss 1.767981, percent error 34.60
# Epoch   207, train loss 0.004058, train error 0.00,  val loss 1.768000, percent error 34.60
# Epoch   208, train loss 0.004058, train error 0.00,  val loss 1.768012, percent error 34.60
# Epoch   209, train loss 0.004058, train error 0.00,  val loss 1.768022, percent error 34.60
# Epoch   210, train loss 0.004058, train error 0.00,  val loss 1.768028, percent error 34.60
# Epoch   211, train loss 0.004058, train error 0.00,  val loss 1.768045, percent error 34.60
# Epoch   212, train loss 0.004057, train error 0.00,  val loss 1.768053, percent error 34.60
# Epoch   213, train loss 0.004057, train error 0.00,  val loss 1.768067, percent error 34.60
# Epoch   214, train loss 0.004057, train error 0.00,  val loss 1.768084, percent error 34.60
# Epoch   215, train loss 0.004057, train error 0.00,  val loss 1.768093, percent error 34.60
# Epoch   216, train loss 0.004057, train error 0.00,  val loss 1.768105, percent error 34.60
# Epoch   217, train loss 0.004056, train error 0.00,  val loss 1.768116, percent error 34.60
# Epoch   218, train loss 0.004056, train error 0.00,  val loss 1.768126, percent error 34.60
# Epoch   219, train loss 0.004056, train error 0.00,  val loss 1.768135, percent error 34.60
# Epoch   220, train loss 0.004056, train error 0.00,  val loss 1.768145, percent error 34.60
# Epoch   221, train loss 0.004056, train error 0.00,  val loss 1.768151, percent error 34.60
# Epoch   222, train loss 0.004056, train error 0.00,  val loss 1.768155, percent error 34.60
# Epoch   223, train loss 0.004056, train error 0.00,  val loss 1.768163, percent error 34.60
# Epoch   224, train loss 0.004055, train error 0.00,  val loss 1.768165, percent error 34.60
# Epoch   225, train loss 0.004055, train error 0.00,  val loss 1.768176, percent error 34.60
# Epoch   226, train loss 0.004055, train error 0.00,  val loss 1.768182, percent error 34.60
# Epoch   227, train loss 0.004055, train error 0.00,  val loss 1.768188, percent error 34.60
# Epoch   228, train loss 0.004055, train error 0.00,  val loss 1.768190, percent error 34.60
# Epoch   229, train loss 0.004055, train error 0.00,  val loss 1.768197, percent error 34.60
# Epoch   230, train loss 0.004055, train error 0.00,  val loss 1.768204, percent error 34.60
# Epoch   231, train loss 0.004055, train error 0.00,  val loss 1.768213, percent error 34.60
# Epoch   232, train loss 0.004055, train error 0.00,  val loss 1.768214, percent error 34.60
# Epoch   233, train loss 0.004055, train error 0.00,  val loss 1.768219, percent error 34.60
# Epoch   234, train loss 0.004054, train error 0.00,  val loss 1.768227, percent error 34.60
# Epoch   235, train loss 0.004054, train error 0.00,  val loss 1.768235, percent error 34.60
# Epoch   236, train loss 0.004054, train error 0.00,  val loss 1.768240, percent error 34.60
# Epoch   237, train loss 0.004054, train error 0.00,  val loss 1.768242, percent error 34.60
# Epoch   238, train loss 0.004054, train error 0.00,  val loss 1.768251, percent error 34.60
# Epoch   239, train loss 0.004054, train error 0.00,  val loss 1.768257, percent error 34.60
# Epoch   240, train loss 0.004054, train error 0.00,  val loss 1.768260, percent error 34.60
# Epoch   241, train loss 0.004054, train error 0.00,  val loss 1.768261, percent error 34.60
# Epoch   242, train loss 0.004054, train error 0.00,  val loss 1.768264, percent error 34.60
# Epoch   243, train loss 0.004054, train error 0.00,  val loss 1.768266, percent error 34.60
# Epoch   244, train loss 0.004054, train error 0.00,  val loss 1.768268, percent error 34.60
# Epoch   245, train loss 0.004054, train error 0.00,  val loss 1.768270, percent error 34.60
# Epoch   246, train loss 0.004054, train error 0.00,  val loss 1.768273, percent error 34.60
# Epoch   247, train loss 0.004054, train error 0.00,  val loss 1.768275, percent error 34.60
# Epoch   248, train loss 0.004054, train error 0.00,  val loss 1.768279, percent error 34.60
# Epoch   249, train loss 0.004054, train error 0.00,  val loss 1.768281, percent error 34.60
# Epoch   250, train loss 0.004054, train error 0.00,  val loss 1.768283, percent error 34.60
# Epoch   251, train loss 0.004054, train error 0.00,  val loss 1.768286, percent error 34.60
# Epoch   252, train loss 0.004054, train error 0.00,  val loss 1.768287, percent error 34.60
# Epoch   253, train loss 0.004054, train error 0.00,  val loss 1.768290, percent error 34.60
# Epoch   254, train loss 0.004053, train error 0.00,  val loss 1.768294, percent error 34.60
# Epoch   255, train loss 0.004053, train error 0.00,  val loss 1.768293, percent error 34.60
# Epoch   256, train loss 0.004053, train error 0.00,  val loss 1.768296, percent error 34.60
# Epoch   257, train loss 0.004053, train error 0.00,  val loss 1.768298, percent error 34.60
# Epoch   258, train loss 0.004053, train error 0.00,  val loss 1.768301, percent error 34.60
# Epoch   259, train loss 0.004053, train error 0.00,  val loss 1.768304, percent error 34.60
# Epoch   260, train loss 0.004053, train error 0.00,  val loss 1.768304, percent error 34.60
# Epoch   261, train loss 0.004053, train error 0.00,  val loss 1.768304, percent error 34.60
# Epoch   262, train loss 0.004053, train error 0.00,  val loss 1.768305, percent error 34.60
# Epoch   263, train loss 0.004053, train error 0.00,  val loss 1.768306, percent error 34.60
# Epoch   264, train loss 0.004053, train error 0.00,  val loss 1.768306, percent error 34.60
# Epoch   265, train loss 0.004053, train error 0.00,  val loss 1.768307, percent error 34.60
# Epoch   266, train loss 0.004053, train error 0.00,  val loss 1.768307, percent error 34.60
# Epoch   267, train loss 0.004053, train error 0.00,  val loss 1.768307, percent error 34.60
# Epoch   268, train loss 0.004053, train error 0.00,  val loss 1.768307, percent error 34.60
# Epoch   269, train loss 0.004053, train error 0.00,  val loss 1.768308, percent error 34.60
# Epoch   270, train loss 0.004053, train error 0.00,  val loss 1.768309, percent error 34.60
# Epoch   271, train loss 0.004053, train error 0.00,  val loss 1.768310, percent error 34.60
# Epoch   272, train loss 0.004053, train error 0.00,  val loss 1.768310, percent error 34.60
# Epoch   273, train loss 0.004053, train error 0.00,  val loss 1.768310, percent error 34.60
# Epoch   274, train loss 0.004053, train error 0.00,  val loss 1.768311, percent error 34.60
# Epoch   275, train loss 0.004053, train error 0.00,  val loss 1.768312, percent error 34.60
# Epoch   276, train loss 0.004053, train error 0.00,  val loss 1.768312, percent error 34.60
# Epoch   277, train loss 0.004053, train error 0.00,  val loss 1.768312, percent error 34.60
# Epoch   278, train loss 0.004053, train error 0.00,  val loss 1.768312, percent error 34.60
# Epoch   279, train loss 0.004053, train error 0.00,  val loss 1.768313, percent error 34.60
# Epoch   280, train loss 0.004053, train error 0.00,  val loss 1.768313, percent error 34.60
# Epoch   281, train loss 0.004053, train error 0.00,  val loss 1.768313, percent error 34.60
# Epoch   282, train loss 0.004053, train error 0.00,  val loss 1.768313, percent error 34.60
# Epoch   283, train loss 0.004053, train error 0.00,  val loss 1.768313, percent error 34.60
# Epoch   284, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   285, train loss 0.004053, train error 0.00,  val loss 1.768313, percent error 34.60
# Epoch   286, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   287, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   288, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   289, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   290, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   291, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   292, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   293, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   294, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   295, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   296, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   297, train loss 0.004053, train error 0.00,  val loss 1.768314, percent error 34.60
# Epoch   298, train loss 0.004053, train error 0.00,  val loss 1.768315, percent error 34.60
# Epoch   299, train loss 0.004053, train error 0.00,  val loss 1.768315, percent error 34.60

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
